# %%
# Install the required packages
# !pip install gymnasium
# !pip install numpy
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gymnasium in c:\users\luis\appdata\roaming\python\python311\site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\programdata\anaconda3\lib\site-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\luis\appdata\roaming\python\python311\site-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\luis\appdata\roaming\python\python311\site-packages (from gymnasium) (0.0.4)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (1.26.4)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\luis\appdata\roaming\python\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import time
from IPython import display

# %% [markdown]
# ## Enviroment Creation

# %%
env = gym.make("MountainCar-v0", render_mode=None)

# Let's see what the observation and action spaces look like
print("Observation Space:", env.observation_space)
print("Action Space:", env.action_space)

# Get the high and low bounds of the state space
print("State space bounds:")
print("Low:", env.observation_space.low)
print("High:", env.observation_space.high)
# Out:
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Discrete(3)
# State space bounds:
# Low: [-1.2  -0.07]
# High: [0.6  0.07]

# %% [markdown]
# gym.make(...): This is the command from the Gymnasium library to create an environment.
#
# 'MountainCar-v0': This is the specific game we want to load.
#
#     The Goal of MountainCar: Imagine a car stuck between two hills. It doesn't have enough engine power to drive straight up the right hill to reach the goal (a flag at the top). The only way to succeed is to drive back and forth, building up momentum, like swinging on a swing set, to eventually climb the hill.
#
# render_mode=None: This tells Gymnasium not to show us a window with the game graphics while it runs. If you wanted to see the car moving, you might change this to render_mode='human'. For just running calculations, None is faster.
#
# env = ...: We store the created game environment in a variable named env. We'll use this variable to interact with the game.

# %% [markdown]
# Observation Space (env.observation_space): This tells us what information the game gives our character (the "agent") at each step. It describes what the agent "sees" or "observes".
#
#     For MountainCar, the output (e.g., Box([-1.2 -0.07], [0.6 0.07], (2,), float32)) means:
#
#         Box: The observations are continuous numbers within a range.
#
#         [position, velocity]: There are two numbers: the car's horizontal position and its current velocity.
#
#         Low: [-1.2 -0.07]: The lowest possible position is -1.2, and the lowest velocity is -0.07.
#
#         High: [0.6 0.07]: The highest possible position is 0.6 (the flag is at 0.5), and the highest velocity is 0.07.

# %% [markdown]
# Action Space (env.action_space): This tells us what actions the character is allowed to take.
#
#     For MountainCar, the output (e.g., Discrete(3)) means:
#
#         Discrete: The actions are distinct choices, numbered starting from 0.
#
#         (3): There are 3 possible actions:
#
#         Action 0: Push the car left.
#
#         Action 1: Do nothing.
#
#         Action 2: Push the car right.

# %%
# Let's run a random episode to see how the environment behaves
state,_ = env.reset()
done=False
steps=0

# %% [markdown]
# state, _ = env.reset():
#
#     env.reset(): This command starts a new episode. It puts the car back at its starting position (usually somewhere random at the bottom of the valley) and resets the game score, time, etc.
#
#     It returns two things: the initial state (the car's starting position and velocity) and some extra info (which we are ignoring here with _).
#
#     We store the starting state in the state variable.
#
# done = False: This is a flag variable. We set it to False at the beginning because the episode is not finished yet.
#
# steps = 0: We initialize a counter to keep track of how many steps we've taken in this episode.

# %%
while not done and steps < 200: # # Maximum steps is typically 200
    action = env.action_space.sample() #Random action
    next_state, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated

    print(f"Step {steps}: State {next_state}, Action {action}, Reward {reward}")
    state = next_state
    steps +=1

print(f"Episode finished after {steps} steps")
env.close()
# Out:
# Step 0: State [-0.44740105 -0.00057069], Action 1, Reward -1.0
# Step 1: State [-4.4753826e-01 -1.3720577e-04], Action 2, Reward -1.0
# Step 2: State [-0.44924095 -0.00170272], Action 0, Reward -1.0
# Step 3: State [-0.45149675 -0.00225579], Action 1, Reward -1.0
# Step 4: State [-0.4542891  -0.00279235], Action 1, Reward -1.0
# Step 5: State [-0.45859754 -0.00430844], Action 0, Reward -1.0
# Step 6: State [-0.4643904  -0.00579286], Action 0, Reward -1.0
# Step 7: State [-0.47062498 -0.00623459], Action 1, Reward -1.0
# Step 8: State [-0.47725523 -0.00663023], Action 1, Reward -1.0
# Step 9: State [-0.4852319  -0.00797668], Action 0, Reward -1.0
# Step 10: State [-0.49249572 -0.0072638 ], Action 2, Reward -1.0
# Step 11: State [-0.49899244 -0.00649673], Action 2, Reward -1.0
# Step 12: State [-0.50467354 -0.00568111], Action 2, Reward -1.0
# Step 13: State [-0.51149654 -0.00682298], Action 0, Reward -1.0
# Step 14: State [-0.51941025 -0.00791372], Action 0, Reward -1.0
# Step 15: State [-0.5283554  -0.00894514], Action 0, Reward -1.0
# Step 16: State [-0.53626484 -0.00790946], Action 2, Reward -1.0
# Step 17: State [-0.54507935 -0.00881449], Action 0, Reward -1.0
# Step 18: State [-0.55473286 -0.0096535 ], Action 0, Reward -1.0
# Step 19: State [-0.5641532  -0.00942033], Action 1, Reward -1.0
# Step 20: State [-0.5722701  -0.00811692], Action 2, Reward -1.0
# Step 21: State [-0.5790233  -0.00675318], Action 2, Reward -1.0
# Step 22: State [-0.5863627  -0.00733941], Action 0, Reward -1.0
# Step 23: State [-0.5932342  -0.00687146], Action 1, Reward -1.0
# Step 24: State [-0.59858716 -0.00535299], Action 2, Reward -1.0
# Step 25: State [-0.6023824  -0.00379531], Action 2, Reward -1.0
# Step 26: State [-0.6045924  -0.00220991], Action 2, Reward -1.0
# Step 27: State [-0.60520077 -0.00060842], Action 2, Reward -1.0
# Step 28: State [-6.0520327e-01 -2.5008558e-06], Action 1, Reward -1.0
# Step 29: State [-6.055998e-01 -3.965623e-04], Action 0, Reward -1.0
# Step 30: State [-0.6043876   0.00121226], Action 2, Reward -1.0
# Step 31: State [-0.60357535  0.00081226], Action 0, Reward -1.0
# Step 32: State [-0.602169    0.00140635], Action 1, Reward -1.0
# Step 33: State [-0.6001788   0.00199018], Action 1, Reward -1.0
# Step 34: State [-0.5966193   0.00355949], Action 2, Reward -1.0
# Step 35: State [-0.5915165   0.00510278], Action 2, Reward -1.0
# Step 36: State [-0.5849079   0.00660864], Action 2, Reward -1.0
# Step 37: State [-0.576842    0.00806587], Action 2, Reward -1.0
# Step 38: State [-0.5683785  0.0084635], Action 1, Reward -1.0
# Step 39: State [-0.55858016  0.00979834], Action 2, Reward -1.0
# Step 40: State [-0.5485199   0.01006022], Action 1, Reward -1.0
# Step 41: State [-0.53927296  0.00924696], Action 0, Reward -1.0
# Step 42: State [-0.5289085   0.01036447], Action 2, Reward -1.0
# Step 43: State [-0.51950425  0.00940429], Action 0, Reward -1.0
# Step 44: State [-0.51013064  0.00937358], Action 1, Reward -1.0
# Step 45: State [-0.50185806  0.0082726 ], Action 0, Reward -1.0
# Step 46: State [-0.49474838  0.00710966], Action 0, Reward -1.0
# Step 47: State [-0.48885483  0.00589355], Action 0, Reward -1.0
# Step 48: State [-0.4842214   0.00463344], Action 0, Reward -1.0
# Step 49: State [-0.4798826  0.0043388], Action 1, Reward -1.0
# Step 50: State [-0.47687072  0.00301187], Action 0, Reward -1.0
# Step 51: State [-0.47520816  0.00166255], Action 0, Reward -1.0
# Step 52: State [-0.4739073  0.0013009], Action 1, Reward -1.0
# Step 53: State [-0.47197768  0.00192959], Action 2, Reward -1.0
# Step 54: State [-0.4714337   0.00054398], Action 0, Reward -1.0
# Step 55: State [-0.47027937  0.00115433], Action 2, Reward -1.0
# Step 56: State [-4.7052324e-01 -2.4385902e-04], Action 0, Reward -1.0
# Step 57: State [-0.4721635  -0.00164025], Action 0, Reward -1.0
# Step 58: State [-0.47518796 -0.00302448], Action 0, Reward -1.0
# Step 59: State [-0.47757426 -0.00238629], Action 2, Reward -1.0
# Step 60: State [-0.47930464 -0.00173038], Action 2, Reward -1.0
# Step 61: State [-0.48236623 -0.0030616 ], Action 0, Reward -1.0
# Step 62: State [-0.4847363  -0.00237006], Action 2, Reward -1.0
# Step 63: State [-0.48639718 -0.00166087], Action 2, Reward -1.0
# Step 64: State [-0.48933646 -0.0029393 ], Action 0, Reward -1.0
# Step 65: State [-0.4915323  -0.00219582], Action 2, Reward -1.0
# Step 66: State [-0.49396822 -0.00243595], Action 1, Reward -1.0
# Step 67: State [-0.49762613 -0.00365788], Action 0, Reward -1.0
# Step 68: State [-0.50047857 -0.00285248], Action 2, Reward -1.0
# Step 69: State [-0.50350434 -0.00302574], Action 1, Reward -1.0
# Step 70: State [-0.5056807  -0.00217636], Action 2, Reward -1.0
# Step 71: State [-0.5069914  -0.00131068], Action 2, Reward -1.0
# Step 72: State [-5.0742656e-01 -4.3518448e-04], Action 2, Reward -1.0
# Step 73: State [-0.508983   -0.00155643], Action 0, Reward -1.0
# Step 74: State [-0.509649   -0.00066601], Action 2, Reward -1.0
# Step 75: State [-0.5104196 -0.0007706], Action 1, Reward -1.0
# Step 76: State [-0.511289   -0.00086942], Action 1, Reward -1.0
# Step 77: State [-0.5122508  -0.00096172], Action 1, Reward -1.0
# Step 78: State [-0.51329756 -0.00104682], Action 1, Reward -1.0
# Step 79: State [-0.5154216  -0.00212407], Action 0, Reward -1.0
# Step 80: State [-0.518607   -0.00318539], Action 0, Reward -1.0
# Step 81: State [-0.52282983 -0.00422282], Action 0, Reward -1.0
# Step 82: State [-0.52605844 -0.00322859], Action 2, Reward -1.0
# Step 83: State [-0.5282686  -0.00221014], Action 2, Reward -1.0
# Step 84: State [-0.5294437  -0.00117512], Action 2, Reward -1.0
# Step 85: State [-5.2957499e-01 -1.3128683e-04], Action 2, Reward -1.0
# Step 86: State [-0.52866143  0.00091353], Action 2, Reward -1.0
# Step 87: State [-5.2870995e-01 -4.8498936e-05], Action 0, Reward -1.0
# Step 88: State [-0.52772015  0.00098983], Action 2, Reward -1.0
# Step 89: State [-0.52669936  0.00102074], Action 1, Reward -1.0
# Step 90: State [-5.266554e-01  4.399698e-05], Action 0, Reward -1.0
# Step 91: State [-0.52558845  0.00106692], Action 2, Reward -1.0
# Step 92: State [-0.52350664  0.00208184], Action 2, Reward -1.0
# Step 93: State [-0.5214255   0.00208115], Action 1, Reward -1.0
# Step 94: State [-0.5203606   0.00106485], Action 0, Reward -1.0
# Step 95: State [-0.51832     0.00204057], Action 2, Reward -1.0
# Step 96: State [-0.51531905  0.00300098], Action 2, Reward -1.0
# Step 97: State [-0.5123802   0.00293889], Action 1, Reward -1.0
# Step 98: State [-0.5105254   0.00185476], Action 0, Reward -1.0
# Step 99: State [-0.50976866  0.00075674], Action 0, Reward -1.0
# Step 100: State [-0.50811565  0.00165304], Action 2, Reward -1.0
# Step 101: State [-0.5065787   0.00153696], Action 1, Reward -1.0
# Step 102: State [-0.5041693   0.00240937], Action 2, Reward -1.0
# Step 103: State [-0.5029056   0.00126373], Action 0, Reward -1.0
# Step 104: State [-0.50179696  0.00110863], Action 1, Reward -1.0
# Step 105: State [-0.50085175  0.00094523], Action 1, Reward -1.0
# Step 106: State [-5.0107700e-01 -2.2523999e-04], Action 0, Reward -1.0
# Step 107: State [-0.500471    0.00060597], Action 2, Reward -1.0
# Step 108: State [-0.49903834  0.00143266], Action 2, Reward -1.0
# Step 109: State [-0.49678972  0.00224862], Action 2, Reward -1.0
# Step 110: State [-0.49474195  0.00204777], Action 1, Reward -1.0
# Step 111: State [-0.49291033  0.00183161], Action 1, Reward -1.0
# Step 112: State [-0.49030855  0.00260177], Action 2, Reward -1.0
# Step 113: State [-0.48895606  0.00135251], Action 0, Reward -1.0
# Step 114: State [-4.888629e-01  9.315889e-05], Action 0, Reward -1.0
# Step 115: State [-0.49002978 -0.00116689], Action 0, Reward -1.0
# Step 116: State [-0.492448   -0.00241823], Action 0, Reward -1.0
# Step 117: State [-0.49509954 -0.00265152], Action 1, Reward -1.0
# Step 118: State [-0.49796453 -0.00286501], Action 1, Reward -1.0
# Step 119: State [-0.5010216  -0.00305707], Action 1, Reward -1.0
# Step 120: State [-0.5032479  -0.00222627], Action 2, Reward -1.0
# Step 121: State [-0.5046267  -0.00137881], Action 2, Reward -1.0
# Step 122: State [-0.5051477  -0.00052102], Action 2, Reward -1.0
# Step 123: State [-0.50580704 -0.00065934], Action 1, Reward -1.0
# Step 124: State [-0.5065998  -0.00079271], Action 1, Reward -1.0
# Step 125: State [-0.5075199  -0.00092015], Action 1, Reward -1.0
# Step 126: State [-0.5085606  -0.00104069], Action 1, Reward -1.0
# Step 127: State [-0.51071405 -0.00215344], Action 0, Reward -1.0
# Step 128: State [-0.5119641  -0.00125005], Action 2, Reward -1.0
# Step 129: State [-0.5133014  -0.00133729], Action 1, Reward -1.0
# Step 130: State [-0.5157159  -0.00241451], Action 0, Reward -1.0
# Step 131: State [-0.5171895  -0.00147363], Action 2, Reward -1.0
# Step 132: State [-0.5187112  -0.00152169], Action 1, Reward -1.0
# Step 133: State [-0.52126956 -0.00255835], Action 0, Reward -1.0
# Step 134: State [-0.5238454  -0.00257582], Action 1, Reward -1.0
# Step 135: State [-0.5274194  -0.00357397], Action 0, Reward -1.0
# Step 136: State [-0.5299647  -0.00254532], Action 2, Reward -1.0
# Step 137: State [-0.53246224 -0.00249757], Action 1, Reward -1.0
# Step 138: State [-0.53389335 -0.00143111], Action 2, Reward -1.0
# Step 139: State [-0.53624725 -0.00235391], Action 0, Reward -1.0
# Step 140: State [-0.53750634 -0.00125907], Action 2, Reward -1.0
# Step 141: State [-0.5396611  -0.00215479], Action 0, Reward -1.0
# Step 142: State [-0.54269546 -0.00303437], Action 0, Reward -1.0
# Step 143: State [-0.5445867  -0.00189122], Action 2, Reward -1.0
# Step 144: State [-0.5473206  -0.00273392], Action 0, Reward -1.0
# Step 145: State [-0.5498768  -0.00255615], Action 1, Reward -1.0
# Step 146: State [-0.55123603 -0.00135927], Action 2, Reward -1.0
# Step 147: State [-0.5523883  -0.00115223], Action 1, Reward -1.0
# Step 148: State [-0.55432487 -0.00193658], Action 0, Reward -1.0
# Step 149: State [-0.5550313  -0.00070646], Action 2, Reward -1.0
# Step 150: State [-5.5450237e-01  5.2893680e-04], Action 2, Reward -1.0
# Step 151: State [-0.553742    0.00076038], Action 1, Reward -1.0
# Step 152: State [-0.55275583  0.00098615], Action 1, Reward -1.0
# Step 153: State [-5.5255133e-01  2.0454766e-04], Action 0, Reward -1.0
# Step 154: State [-5.5212986e-01  4.2141875e-04], Action 1, Reward -1.0
# Step 155: State [-0.55049473  0.00163514], Action 2, Reward -1.0
# Step 156: State [-0.54865813  0.00183664], Action 1, Reward -1.0
# Step 157: State [-0.5456337   0.00302441], Action 2, Reward -1.0
# Step 158: State [-0.54344416  0.00218955], Action 0, Reward -1.0
# Step 159: State [-0.54210585  0.0013383 ], Action 0, Reward -1.0
# Step 160: State [-5.4162884e-01  4.7703565e-04], Action 0, Reward -1.0
# Step 161: State [-5.4201663e-01 -3.8780502e-04], Action 0, Reward -1.0
# Step 162: State [-0.5412664   0.00075026], Action 2, Reward -1.0
# Step 163: State [-0.54038364  0.0008827 ], Action 1, Reward -1.0
# Step 164: State [-0.53837514  0.00200854], Action 2, Reward -1.0
# Step 165: State [-0.5352558   0.00311932], Action 2, Reward -1.0
# Step 166: State [-0.53304905  0.00220673], Action 0, Reward -1.0
# Step 167: State [-0.5317715  0.0012776], Action 0, Reward -1.0
# Step 168: State [-0.5304326   0.00133889], Action 1, Reward -1.0
# Step 169: State [-0.5290424   0.00139014], Action 1, Reward -1.0
# Step 170: State [-0.5276115   0.00143096], Action 1, Reward -1.0
# Step 171: State [-0.5261504   0.00146106], Action 1, Reward -1.0
# Step 172: State [-0.5246702  0.0014802], Action 1, Reward -1.0
# Step 173: State [-0.522182    0.00248823], Action 2, Reward -1.0
# Step 174: State [-0.51870435  0.00347761], Action 2, Reward -1.0
# Step 175: State [-0.5162635  0.0024409], Action 0, Reward -1.0
# Step 176: State [-0.51487756  0.00138589], Action 0, Reward -1.0
# Step 177: State [-0.5125571   0.00232049], Action 2, Reward -1.0
# Step 178: State [-0.5103194   0.00223769], Action 1, Reward -1.0
# Step 179: State [-0.50918126  0.00113812], Action 0, Reward -1.0
# Step 180: State [-5.0915128e-01  3.0023737e-05], Action 0, Reward -1.0
# Step 181: State [-0.5102296 -0.0010783], Action 0, Reward -1.0
# Step 182: State [-0.5124081  -0.00217854], Action 0, Reward -1.0
# Step 183: State [-0.51567054 -0.00326246], Action 0, Reward -1.0
# Step 184: State [-0.5189925  -0.00332191], Action 1, Reward -1.0
# Step 185: State [-0.5233489  -0.00435646], Action 0, Reward -1.0
# Step 186: State [-0.52670723 -0.00335833], Action 2, Reward -1.0
# Step 187: State [-0.5290423  -0.00233502], Action 2, Reward -1.0
# Step 188: State [-0.5323365  -0.00329419], Action 0, Reward -1.0
# Step 189: State [-0.53456515 -0.00222867], Action 2, Reward -1.0
# Step 190: State [-0.5357116  -0.00114644], Action 2, Reward -1.0
# Step 191: State [-0.5377672  -0.00205561], Action 0, Reward -1.0
# Step 192: State [-0.5407166  -0.00294938], Action 0, Reward -1.0
# Step 193: State [-0.5445376  -0.00382105], Action 0, Reward -1.0
# Step 194: State [-0.54720175 -0.00266411], Action 2, Reward -1.0
# Step 195: State [-0.550689   -0.00348724], Action 0, Reward -1.0
# Step 196: State [-0.55497324 -0.00428429], Action 0, Reward -1.0
# Step 197: State [-0.5590226  -0.00404933], Action 1, Reward -1.0
# Step 198: State [-0.5628067  -0.00378415], Action 1, Reward -1.0
# Step 199: State [-0.56729746 -0.00449076], Action 0, Reward -1.0
# Episode finished after 200 steps

# %% [markdown]
# while not done and steps < 200:: This loop continues as long as the episode is not done AND the number of steps taken is less than 200.
#
#     MountainCar usually has a time limit (200 steps). If the car doesn't reach the flag within 200 steps, the episode ends.
#
# action = env.action_space.sample(): This is where we choose an action. env.action_space.sample() randomly picks one of the valid actions (0, 1, or 2). Crucially, this is NOT intelligent decision-making; it's just random.
#
# next_state, reward, terminated, truncated, info = env.step(action): This is the MOST IMPORTANT command. We tell the environment (env) to take the chosen action. The game then calculates what happens next and gives us back five pieces of information:
#
#     next_state: The new observation (the car's new position and velocity) after taking the action.
#
#     reward: A score signal. In MountainCar, you typically get a reward of -1 for every single step you take. This encourages the agent to finish as quickly as possible. You get a reward of 0 (or sometimes positive) if you reach the flag.
#
#     terminated: A boolean (True or False). It becomes True if the episode ended because the agent reached the goal state (car reached the flag).
#
#     truncated: A boolean (True or False). It becomes True if the episode ended for another reason, like hitting the step limit (200 steps).
#
#     info: Extra dictionary with debugging information (usually empty in basic environments).
#
# done = terminated or truncated: We update our done flag. The episode is considered "done" if it either terminated (goal reached) OR truncated (time ran out).
#
# print(...): We display the information for the step we just took.
#
# state = next_state: We update our current state to be the next_state we just received. This is important for the next loop iteration (though in this random example, we don't use the state to decide the next action).
#
# steps += 1: We increment our step counter.

# %% [markdown]
# Run this code first. It will:
#
# Create the MountainCar environment
#
# Show you the observation space (position and velocity ranges)
#
# Show you the action space (the three possible actions)
#
# Run a random agent to demonstrate the environment's behavior
